# %%
# import sys
# print(sys.executable)

# import tensorflow as tf
# print(tf.__version__)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import os
 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
microsoft_cvs = '../../../Yahoo_Finance/Microsoft/MSFT_historical_data.csv'
df = pd.read_csv(microsoft_cvs)
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1986-03-13    0.088542    0.101563    0.088542    0.097222    0.059125
# 1      1986-03-14    0.097222    0.102431    0.097222    0.100694    0.061237
# 2      1986-03-17    0.100694    0.103299    0.100694    0.102431    0.062293
# 3      1986-03-18    0.102431    0.103299    0.098958    0.099826    0.060709
# 4      1986-03-19    0.099826    0.100694    0.097222    0.098090    0.059653
# ...           ...         ...         ...         ...         ...         ...
# 10171  2026-07-29  393.399994  401.250000  388.739990  390.540009  390.540009
# 10172  2026-07-30  437.899994  458.690002  432.440002  451.100006  451.100006
# 10173  2026-07-31  450.000000  466.839996  449.329987  464.720001  464.720001
# 10174  2026-08-03  476.130005  491.649994  475.000000  487.649994  487.649994
# 10175  2026-08-04  480.755005  489.950012  479.170013  488.670013  488.670013
#
#            Volume
# 0      1031788800
# 1       308160000
# 2       133171200
# 3        67766400
# 4        47894400
# ...           ...
# 10171    47209000
# 10172   110160700
# 10173    60846000
# 10174    66651900
# 10175     8231301
#
# [10176 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)
df = df.dropna().reset_index(drop=True)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.059125
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.061237
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.062293
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.060709
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.059653
# ...          ...         ...         ...         ...         ...         ...
# 10171 2026-07-29  393.399994  401.250000  388.739990  390.540009  390.540009
# 10172 2026-07-30  437.899994  458.690002  432.440002  451.100006  451.100006
# 10173 2026-07-31  450.000000  466.839996  449.329987  464.720001  464.720001
# 10174 2026-08-03  476.130005  491.649994  475.000000  487.649994  487.649994
# 10175 2026-08-04  480.755005  489.950012  479.170013  488.670013  488.670013
#
#            Volume
# 0      1031788800
# 1       308160000
# 2       133171200
# 3        67766400
# 4        47894400
# ...           ...
# 10171    47209000
# 10172   110160700
# 10173    60846000
# 10174    66651900
# 10175     8231301
#
# [10176 rows x 7 columns]

# %%
target = 'Close'
prices = df[[target]].values

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_prices = scaler.fit_transform(prices)

# %%
PAST = 3
FUTURE = 30

def create_sequences(data, past, future):
    X, y = [], []
    for i in range(len(data) - past - future +1):
        X.append(data[i : i + past, 0])
        y.append(data[i + past + future - 1, 0])
    return np.array(X), np.array(y)


X, y = create_sequences(scaled_prices, PAST, FUTURE)
print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (10144, 3)
# y shape: (10144,)

# %%
# Train and Test the Splits

split_idx = int(len(X) * 0.8)

X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f'training samples: {len(X_train)}, testing samples: {len(X_test)}')
# Out:
# training samples: 8115, testing samples: 2029

# %%
model = XGBRegressor(
    n_estimators = 300,
    max_depth = 4,
    learning_rate = 0.05,
    early_stopping_rounds = 10,
    eval_metric = 'rmse'
)

model.fit(
    X_train, y_train,
    eval_set = [(X_test, y_test)],
    verbose = True
)
# Out:
# [0]	validation_0-rmse:0.53628
# [1]	validation_0-rmse:0.53071
# [2]	validation_0-rmse:0.52555
# [3]	validation_0-rmse:0.52053
# [4]	validation_0-rmse:0.51588
# [5]	validation_0-rmse:0.51147
# [91]	validation_0-rmse:0.42169
# [92]	validation_0-rmse:0.42164
# [93]	validation_0-rmse:0.42154
# [94]	validation_0-rmse:0.42150
# [95]	validation_0-rmse:0.42140
# [96]	validation_0-rmse:0.42138
# [97]	validation_0-rmse:0.42128
# [98]	validation_0-rmse:0.42126
# [99]	validation_0-rmse:0.42124
# [100]	validation_0-rmse:0.42115
# [101]	validation_0-rmse:0.42112
# [102]	validation_0-rmse:0.42110
# [103]	validation_0-rmse:0.42108
# [104]	validation_0-rmse:0.42105
# [105]	validation_0-rmse:0.42104
# [106]	validation_0-rmse:0.42102
# [107]	validation_0-rmse:0.42101
# [108]	validation_0-rmse:0.42094
# [109]	validation_0-rmse:0.42092
# [110]	validation_0-rmse:0.42092
# [111]	validation_0-rmse:0.42090
# [112]	validation_0-rmse:0.42083
# [113]	validation_0-rmse:0.42082
# [114]	validation_0-rmse:0.42078
# [115]	validation_0-rmse:0.42075
# [116]	validation_0-rmse:0.42073
# [117]	validation_0-rmse:0.42072
# [118]	validation_0-rmse:0.42071
# [119]	validation_0-rmse:0.42070
# [120]	validation_0-rmse:0.42070
# [121]	validation_0-rmse:0.42067
# [122]	validation_0-rmse:0.42066
# [123]	validation_0-rmse:0.42066
# [124]	validation_0-rmse:0.42064
# [125]	validation_0-rmse:0.42063
# [126]	validation_0-rmse:0.42059
# [127]	validation_0-rmse:0.42059
# [128]	validation_0-rmse:0.42058
# [129]	validation_0-rmse:0.42055
# [130]	validation_0-rmse:0.42055
# [131]	validation_0-rmse:0.42055
# [132]	validation_0-rmse:0.42054
# [133]	validation_0-rmse:0.42051
# [134]	validation_0-rmse:0.42051
# [135]	validation_0-rmse:0.42050
# [136]	validation_0-rmse:0.42046
# [137]	validation_0-rmse:0.42046
# [138]	validation_0-rmse:0.42042
# [139]	validation_0-rmse:0.42042
# [140]	validation_0-rmse:0.42042
# [141]	validation_0-rmse:0.42041
# [142]	validation_0-rmse:0.42037
# [143]	validation_0-rmse:0.42035
# [144]	validation_0-rmse:0.42036
# [145]	validation_0-rmse:0.42035
# [146]	validation_0-rmse:0.42035
# [147]	validation_0-rmse:0.42032
# [148]	validation_0-rmse:0.42029
# [149]	validation_0-rmse:0.42028
# [150]	validation_0-rmse:0.42026
# [151]	validation_0-rmse:0.42026
# [152]	validation_0-rmse:0.42026
# [153]	validation_0-rmse:0.42026
# [154]	validation_0-rmse:0.42025
# [155]	validation_0-rmse:0.42023
# [156]	validation_0-rmse:0.42023
# [157]	validation_0-rmse:0.42022
# [158]	validation_0-rmse:0.42022
# [159]	validation_0-rmse:0.42022
# [160]	validation_0-rmse:0.42018
# [161]	validation_0-rmse:0.42018
# [162]	validation_0-rmse:0.42018
# [163]	validation_0-rmse:0.42017
# [164]	validation_0-rmse:0.42017
# [165]	validation_0-rmse:0.42017
# [166]	validation_0-rmse:0.42016
# [167]	validation_0-rmse:0.42016
# [168]	validation_0-rmse:0.42015
# [169]	validation_0-rmse:0.42012
# [170]	validation_0-rmse:0.42012
# [171]	validation_0-rmse:0.42012
# [172]	validation_0-rmse:0.42011
# [173]	validation_0-rmse:0.42008
# [174]	validation_0-rmse:0.42008
# [175]	validation_0-rmse:0.42005
# [176]	validation_0-rmse:0.42005
# [177]	validation_0-rmse:0.42005
# [178]	validation_0-rmse:0.42003
# [179]	validation_0-rmse:0.42003
# [180]	validation_0-rmse:0.42003
# [181]	validation_0-rmse:0.42001
# [182]	validation_0-rmse:0.42000
# [183]	validation_0-rmse:0.42000
# [184]	validation_0-rmse:0.42000
# [185]	validation_0-rmse:0.42000
# [186]	validation_0-rmse:0.42000
# [187]	validation_0-rmse:0.42000
# [188]	validation_0-rmse:0.42000
# [189]	validation_0-rmse:0.41997
# [190]	validation_0-rmse:0.41997
# [191]	validation_0-rmse:0.41997
# [192]	validation_0-rmse:0.41995
# [193]	validation_0-rmse:0.41995
# [194]	validation_0-rmse:0.41994
# [195]	validation_0-rmse:0.41994
# [196]	validation_0-rmse:0.41994
# [197]	validation_0-rmse:0.41994
# [198]	validation_0-rmse:0.41994
# [199]	validation_0-rmse:0.41994
# [200]	validation_0-rmse:0.41994
# [201]	validation_0-rmse:0.41994
# [202]	validation_0-rmse:0.41994
# [203]	validation_0-rmse:0.41994
# [204]	validation_0-rmse:0.41994
# [205]	validation_0-rmse:0.41994
# [206]	validation_0-rmse:0.41994
# [207]	validation_0-rmse:0.41992
# [208]	validation_0-rmse:0.41992
# [209]	validation_0-rmse:0.41992
# [210]	validation_0-rmse:0.41992
# [211]	validation_0-rmse:0.41992
# [212]	validation_0-rmse:0.41992
# [213]	validation_0-rmse:0.41992
# [214]	validation_0-rmse:0.41992
# [215]	validation_0-rmse:0.41992
# [216]	validation_0-rmse:0.41992
# [217]	validation_0-rmse:0.41992
# [218]	validation_0-rmse:0.41992
# [219]	validation_0-rmse:0.41992
# [220]	validation_0-rmse:0.41992
# [221]	validation_0-rmse:0.41991
# [222]	validation_0-rmse:0.41991
# [223]	validation_0-rmse:0.41991
# [224]	validation_0-rmse:0.41991
# [225]	validation_0-rmse:0.41991
# [226]	validation_0-rmse:0.41991
# [227]	validation_0-rmse:0.41991
# [228]	validation_0-rmse:0.41991
# [229]	validation_0-rmse:0.41991
# [230]	validation_0-rmse:0.41990
# [231]	validation_0-rmse:0.41990
# [232]	validation_0-rmse:0.41990
# [233]	validation_0-rmse:0.41990
# [234]	validation_0-rmse:0.41990
# [235]	validation_0-rmse:0.41989
# [236]	validation_0-rmse:0.41990
# [237]	validation_0-rmse:0.41990
# [238]	validation_0-rmse:0.41990
# [239]	validation_0-rmse:0.41990
# [240]	validation_0-rmse:0.41990
# [241]	validation_0-rmse:0.41990
# [242]	validation_0-rmse:0.41990
# [243]	validation_0-rmse:0.41990
# [244]	validation_0-rmse:0.41990
# [245]	validation_0-rmse:0.41990
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=True, eval_metric='rmse', feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test,y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f'rmse: ${rmse:.2f}, mae: ${mae:.2f}, mape: {mape:.2f}%')
# Out:
# rmse: $0.42, mae: $0.36, mape: 58.17%

# %%
final_model = XGBRegressor(
    n_estimators = model.best_iteration,
    max_depth = 4,
    learning_rate = 0.05
)
final_model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=235,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
os.makedirs('export', exist_ok=True)
joblib.dump(final_model, 'export/microsoft_xgb_model.pkl')
# Out:
# ['export/microsoft_xgb_model.pkl']

# %%
plot_importance(model)
plt.show()
