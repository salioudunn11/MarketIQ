# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
prices = ticker.history(period="5y")

# %%
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-08-04 00:00:00-04:00  143.551720  144.058580  142.586710  143.239792
# 2021-08-05 00:00:00-04:00  143.269033  144.107321  142.479487  143.347015
# 2021-08-06 00:00:00-04:00  142.868692  143.610608  142.165818  142.663681
# 2021-08-09 00:00:00-04:00  142.722237  143.210343  142.058420  142.614853
# 2021-08-10 00:00:00-04:00  142.956566  144.196360  141.843684  142.136551
# ...                               ...         ...         ...         ...
# 2026-07-29 00:00:00-04:00  339.730011  344.570007  337.350006  338.190002
# 2026-07-30 00:00:00-04:00  333.100006  334.750000  329.589996  333.429993
# 2026-07-31 00:00:00-04:00  304.809998  310.690002  300.000000  308.910004
# 2026-08-03 00:00:00-04:00  309.579987  311.799988  302.559998  303.420013
# 2026-08-04 00:00:00-04:00  302.725006  305.399994  301.320007  305.234985
#
#                               Volume  Dividends  Stock Splits
# Date
# 2021-08-04 00:00:00-04:00   56368300       0.00           0.0
# 2021-08-05 00:00:00-04:00   46397700       0.00           0.0
# 2021-08-06 00:00:00-04:00   54126800       0.22           0.0
# 2021-08-09 00:00:00-04:00   48908700       0.00           0.0
# 2021-08-10 00:00:00-04:00   69023100       0.00           0.0
# ...                              ...        ...           ...
# 2026-07-29 00:00:00-04:00   56090800       0.00           0.0
# 2026-07-30 00:00:00-04:00   74817800       0.00           0.0
# 2026-07-31 00:00:00-04:00  132489100       0.00           0.0
# 2026-08-03 00:00:00-04:00   74824300       0.00           0.0
# 2026-08-04 00:00:00-04:00   11687917       0.00           0.0
#
# [1255 rows x 7 columns]

# %%
from fredapi import Fred

fred = Fred(api_key="FRED_API_KEY")

inflation = fred.get_series("CPIAUCSL")
interest = fred.get_series("FEDFUNDS")

# %%
from fredapi import Fred

fred = Fred(api_key="FRED_API_KEY")

# %%
from dotenv import load_dotenv
import os
from fredapi import Fred

load_dotenv() 
fred = Fred(api_key=os.environ["FRED_API_KEY"])

# %%
inflation = fred.get_series("CPIAUCSL")
interest = fred.get_series("FEDFUNDS")

# %%
inflation
# Out:
# 1947-01-01     21.480
# 1947-02-01     21.620
# 1947-03-01     22.000
# 1947-04-01     22.000
# 1947-05-01     21.950
#                ...
# 2026-02-01    327.460
# 2026-03-01    330.293
# 2026-04-01    332.407
# 2026-05-01    333.979
# 2026-06-01    332.568
# Length: 954, dtype: float64

# %%
interest
# Out:
# 1954-07-01    0.80
# 1954-08-01    1.22
# 1954-09-01    1.07
# 1954-10-01    0.85
# 1954-11-01    0.83
#               ...
# 2026-03-01    3.64
# 2026-04-01    3.64
# 2026-05-01    3.63
# 2026-06-01    3.63
# 2026-07-01    3.63
# Length: 865, dtype: float64

# %%
import pandas as pd
import numpy as np
